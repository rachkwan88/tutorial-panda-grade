# %%
# !pip3 install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 11.0 MB 1.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 502 kB 34.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 346 kB 41.1 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.3.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
#load panda library
import pandas as pd

# %%
#load student.csv into a dataframe
df = pd.read_csv('student.csv')

# %%
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df.tail()
# Out:
#     id         name  class  mark  gender
# 30  31  Marry Toeey   Four    88    male
# 31  32    Binn Rott  Seven    90  female
# 32  33    Kenn Rein    Six    96  female
# 33  34     Gain Toe  Seven    69    male
# 34  35   Rows Noump    Six    88  female

# %%
df.shape
# Out:
# (35, 5)

# %%
df.columns.tolist()
# Out:
# ['id', 'name', 'class', 'mark', 'gender']

# %%
df.describe()
# Out:
#               id       mark
# count  35.000000  35.000000
# mean   18.000000  74.657143
# std    10.246951  16.401117
# min     1.000000  18.000000
# 25%     9.500000  62.500000
# 50%    18.000000  79.000000
# 75%    26.500000  88.000000
# max    35.000000  96.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      35 non-null     int64
#  1   name    35 non-null     object
#  2   class   35 non-null     object
#  3   mark    35 non-null     int64
#  4   gender  35 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB

# %%
df['mark']
# Out:
# 0     75
# 1     85
# 2     55
# 3     60
# 4     60
# 5     55
# 6     78
# 7     85
# 8     78
# 9     55
# 10    89
# 11    94
# 12    88
# 13    88
# 14    88
# 15    88
# 16    54
# 17    75
# 18    18
# 19    65
# 20    69
# 21    55
# 22    79
# 23    78
# 24    88
# 25    79
# 26    81
# 27    86
# 28    55
# 29    79
# 30    88
# 31    90
# 32    96
# 33    69
# 34    88
# Name: mark, dtype: int64

# %%
#calculate the mean
df['mark'].mean()
# Out:
# 74.65714285714286

# %%
#filter female students
df_female = df[df['gender']=='female']

# %%
#calculate average of female students
df_female['mark'].mean()
# Out:
# 77.52941176470588

# %%
df_male = df[df['gender']=='male']
df_male['mark'].mean()
# Out:
# 71.94444444444444

# %%
df_female.head()
# Out:
#     id        name class  mark  gender
# 0    1    John Deo  Four    75  female
# 3    4  Krish Star  Four    60  female
# 4    5   John Mike  Four    60  female
# 9   10    Big John  Four    55  female
# 10  11      Ronald   Six    89  female

# %%
df_nine_female = df.groupby('class').head()
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 21  22       Reggid  Seven    55  female
# 22  23        Herod  Eight    79    male
# 23  24    Tiddy Now  Seven    78    male
# 24  25     Giff Tow  Seven    88    male
# ...

# %%
df_nine_female = df_female[df_female['class']=='Four']
df_nine_female
# Out:
#     id        name class  mark  gender
# 0    1    John Deo  Four    75  female
# 3    4  Krish Star  Four    60  female
# 4    5   John Mike  Four    60  female
# 9   10    Big John  Four    55  female
# 20  21  Babby John  Four    69  female

# %%
# derive a new column called grade which takes in conditionals. it will be based on the mark. If mark is greater than 70, put A in the derived column, if mark is greater than 60, put B in the derived column, if mark is greater than 50, put C in the derived column, if mark is greater than 40, put D in the derived column, if mark is less than 40, put E in the derived column
df['grade'] = df['mark'].apply(lambda x: 'A' if x > 70 else 'B' if x > 60 else 'C' if x > 50 else 'D' if x > 40 else 'E')
df.head()
# Out:
#    id        name  class  mark  gender grade
# 0   1    John Deo   Four    75  female     A
# 1   2    Max Ruin  Three    85    male     A
# 2   3      Arnold  Three    55    male     C
# 3   4  Krish Star   Four    60  female     C
# 4   5   John Mike   Four    60  female     C

# %%
df_nine_female
# Out:
#     id        name class  mark  gender  mark10
# 0    1    John Deo  Four    75  female     750
# 3    4  Krish Star  Four    60  female     600
# 4    5   John Mike  Four    60  female     600
# 9   10    Big John  Four    55  female     550
# 20  21  Babby John  Four    69  female     690

# %%
import numpy as np

# Assuming df is already defined and it has 'gender' and 'marks' columns
female_df = df[df['gender'] == 'female']
male_df = df[df['gender'] == 'male']

bins = np.linspace(df['mark'].min(), df['mark'].max(), 30)

plt.hist([female_df['mark'], male_df['mark']], bins, label=['Female', 'Male'], stacked=False, rwidth=0.8)
plt.legend(loc='upper right')
plt.show()
